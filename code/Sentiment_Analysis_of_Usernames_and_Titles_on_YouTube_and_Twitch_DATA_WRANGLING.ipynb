# %% [markdown]
# # Sentiment Analysis of Usernames and Titles on YouTube and Twitch
#
# ## Data Preperation, Wrangling and Cleaning
#
# This notebook concatenates all the files that were pushed on a scheduled basis from the social media platforms to GitHub.
#
# The data is then filtered from the 28th of May 2021 till the 28th of July 2021. The textual data is processed, cleaned and made ready for visualisatioin and sentiment analysis

# %% [markdown]
# ## Setting up environments

# %%
# !python -m spacy download en_core_web_lg
# Out:
# Collecting en_core_web_lg==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.2.5/en_core_web_lg-2.2.5.tar.gz (827.9 MB)
#      |████████████████████████████████| 827.9 MB 1.2 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_lg==2.2.5) (2.2.4)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.1.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.5)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (4.41.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (57.2.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.0.5)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (1.19.5)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (0.4.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (2.23.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (2.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (3.0.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (7.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_lg==2.2.5) (0.8.2)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (4.6.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_lg==2.2.5) (3.5.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_lg==2.2.5) (2021.5.30)
# Building wheels for collected packages: en-core-web-lg
#   Building wheel for en-core-web-lg (setup.py) ... done
#   Created wheel for en-core-web-lg: filename=en_core_web_lg-2.2.5-py3-none-any.whl size=829180943 sha256=30e0efff01b79fe13856dcf9b1d866a81418cc1d2bf72b4e76a3f73553625007
#   Stored in directory: /tmp/pip-ephem-wheel-cache-f7gqt_n0/wheels/11/95/ba/2c36cc368c0bd339b44a791c2c1881a1fb714b78c29a4cb8f5
# Successfully built en-core-web-lg
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-2.2.5
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')

# %%
# !pip install PyGithub
# Out:
# Collecting PyGithub
#   Downloading PyGithub-1.55-py3-none-any.whl (291 kB)
#      |████████████████████████████████| 291 kB 11.0 MB/s
# Collecting deprecated
#   Downloading Deprecated-1.2.12-py2.py3-none-any.whl (9.5 kB)
# Collecting pynacl>=1.4.0
#   Downloading PyNaCl-1.4.0-cp35-abi3-manylinux1_x86_64.whl (961 kB)
#      |████████████████████████████████| 961 kB 20.5 MB/s
# Requirement already satisfied: requests>=2.14.0 in /usr/local/lib/python3.7/dist-packages (from PyGithub) (2.23.0)
# Collecting pyjwt>=2.0
#   Downloading PyJWT-2.1.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from pynacl>=1.4.0->PyGithub) (1.15.0)
# Requirement already satisfied: cffi>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from pynacl>=1.4.0->PyGithub) (1.14.6)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.4.1->pynacl>=1.4.0->PyGithub) (2.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.14.0->PyGithub) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.14.0->PyGithub) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.14.0->PyGithub) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.14.0->PyGithub) (3.0.4)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated->PyGithub) (1.12.1)
# Installing collected packages: pynacl, pyjwt, deprecated, PyGithub
# Successfully installed PyGithub-1.55 deprecated-1.2.12 pyjwt-2.1.0 pynacl-1.4.0

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scipy) (1.19.5)

# %% [markdown]
# ## Ingesting Data

# %%
# !git clone https://github.com/JefNtungila/master_thesis.git
# Out:
# Cloning into 'master_thesis'...
# remote: Enumerating objects: 6719, done.
# remote: Counting objects: 100% (228/228), done.
# remote: Compressing objects: 100% (228/228), done.
# remote: Total 6719 (delta 92), reused 0 (delta 0), pack-reused 6491
# Receiving objects: 100% (6719/6719), 19.41 MiB | 18.89 MiB/s, done.
# Resolving deltas: 100% (3535/3535), done.

# %%
# %%time

# !cp master_thesis/* /content/master_thesis/
# Out:
# cp: 'master_thesis/twitch_2021-05-16T17:14:29.983501.csv' and '/content/master_thesis/twitch_2021-05-16T17:14:29.983501.csv' are the same file
# cp: 'master_thesis/twitch_2021-05
csv' are the same file
# cp: 'master_thesis/youtube_2021-07-27T14:37:06.760555.csv' and '/content/master_thesis/youtube_2021-07-27T14:37:06.760555.csv' are the same file
# cp: 'master_thesis/youtube_2021-07-27T20:37:07.424223.csv' and '/content/master_thesis/youtube_2021-07-27T20:37:07.424223.csv' are the same file
# cp: 'master_thesis/youtube_2021-07-28T02:37:06.728237.csv' and '/content/master_thesis/youtube_2021-07-28T02:37:06.728237.csv' are the same file
# cp: 'master_thesis/youtube_2021-07-28T08:37:07.419593.csv' and '/content/master_thesis/youtube_2021-07-28T08:37:07.419593.csv' are the same file
# cp: 'master_thesis/youtube_2021-07-28T14:37:06.796839.csv' and '/content/master_thesis/youtube_2021-07-28T14:37:06.796839.csv' are the same file
# cp: 'master_thesis/youtube_2021-07-28T20:37:07.375345.csv' and '/content/master_thesis/youtube_2021-07-28T20:37:07.375345.csv' are the same file
# cp: 'master_thesis/youtube_2021-07-29T02:37:05.898203.csv' and '/content/master_thesis/youtube_2021-07-29T02:37:05.898203.csv' are the same file
# cp: 'master_thesis/youtube_2021-07-29T08:37:07.865471.csv' and '/content/master_thesis/youtube_2021-07-29T08:37:07.865471.csv' are the same file
# cp: 'master_thesis/youtube_2021-07-29T14:37:06.579224.csv' and '/content/master_thesis/youtube_2021-07-29T14:37:06.579224.csv' are the same file
# cp: 'master_thesis/youtube_2021-07-29T20:37:08.733515.csv' and '/content/master_thesis/youtube_2021-07-29T20:37:08.733515.csv' are the same file
# cp: 'master_thesis/youtube_2021-07-30T02:37:05.595348.csv' and '/content/master_thesis/youtube_2021-07-30T02:37:05.595348.csv' are the same file
# cp: 'master_thesis/youtube_2021-07-30T08:37:07.512304.csv' and '/content/master_thesis/youtube_2021-07-30T08:37:07.512304.csv' are the same file
# cp: 'master_thesis/youtube_2021-07-30T14:37:06.183942.csv' and '/content/master_thesis/youtube_2021-07-30T14:37:06.183942.csv' are the same file
# cp: 'master_thesis/youtube_2021-07-30T20:37:08.479658.csv' and '/content/master_thesis/youtube_2021-07-30T20:37:08.479658.csv' are the same file
# cp: 'master_thesis/youtube_2021-07-31T02:37:08.104772.csv' and '/content/master_thesis/youtube_2021-07-31T02:37:08.104772.csv' are the same file
# cp: 'master_thesis/youtube_2021-07-31T08:37:07.926706.csv' and '/content/master_thesis/youtube_2021-07-31T08:37:07.926706.csv' are the same file
# cp: 'master_thesis/youtube_2021-07-31T14:37:06.098608.csv' and '/content/master_thesis/youtube_2021-07-31T14:37:06.098608.csv' are the same file
# cp: 'master_thesis/youtube_2021-07-31T20:37:07.859793.csv' and '/content/master_thesis/youtube_2021-07-31T20:37:07.859793.csv' are the same file
# cp: 'master_thesis/youtube_2021-08-01T02:37:06.725699.csv' and '/content/master_thesis/youtube_2021-08-01T02:37:06.725699.csv' are the same file
# cp: 'master_thesis/youtube_2021-08-01T08:37:07.303961.csv' and '/content/master_thesis/youtube_2021-08-01T08:37:07.303961.csv' are the same file
# cp: 'master_thesis/youtube_2021-08-01T14:37:05.863425.csv' and '/content/master_thesis/youtube_2021-08-01T14:37:05.863425.csv' are the same file
# cp: 'master_thesis/youtube_2021-08-01T20:37:07.599508.csv' and '/content/master_thesis/youtube_2021-08-01T20:37:07.599508.csv' are the same file
# cp: 'master_thesis/youtube_2021-08-02T02:37:08.378005.csv' and '/content/master_thesis/youtube_2021-08-02T02:37:08.378005.csv' are the same file
# cp: 'master_thesis/youtube_2021-08-02T08:37:10.218370.csv' and '/content/master_thesis/youtube_2021-08-02T08:37:10.218370.csv' are the same file
# cp: 'master_thesis/youtube_2021-08-02T14:37:06.527380.csv' and '/content/master_thesis/youtube_2021-08-02T14:37:06.527380.csv' are the same file
# cp: 'master_thesis/youtube_2021-08-02T20:37:07.493368.csv' and '/content/master_thesis/youtube_2021-08-02T20:37:07.493368.csv' are the same file
# CPU times: user 52 ms, sys: 24 ms, total: 76 ms
# Wall time: 575 ms

# %%
# import OS module
import os
import pandas as pd

pd.options.display.max_colwidth = 100

# Get the list of all files and directories
#saved in the master thesis directory
path = '/content/master_thesis/'
dir_list = os.listdir(path)
 
#reading the files in as csv, appending them to a list, concatinating them as a whole 
twitch_files = pd.concat([pd.read_csv(f'{path}{file_}') for file_ in dir_list if 'twitch' in file_])
youtube_files = pd.concat([pd.read_csv(f'{path}{file_}') for file_ in dir_list if 'youtube' in file_])

print(len(twitch_files))
print(len(youtube_files))
# Out:
# 186800
# 12947

# %% [markdown]
# ## Data Wrangling and Cleaning

# %%
# %time
from spacy.tokenizer import Tokenizer
import spacy
import html
from html.parser import HTMLParser
import re

#loading spacy encore model - need pip install it and restart runtime
nlp = spacy.load('en_core_web_lg')
tokenizer = Tokenizer(nlp.vocab)
# Out:
# CPU times: user 2 µs, sys: 0 ns, total: 2 µs
# Wall time: 4.05 µs

# %%
def token_text(doc):
  '''
  formatting as non html for visualisation
  keep only characters 
  tokenise sentence into words if those words are not punctuation, pronouns or stop words 
  '''
  doc = html.parser.unescape(doc) #remove html
  doc = re.sub(r'[^a-zA-Z ^0-9]', '', doc) #keep alphanumerical characters
  doc = re.sub('[0-9]+', '', doc) #remove numerical characters
  doc = doc.lower() #convert all strings to lowercase
  tokens = [token.text for token in tokenizer(doc)  if (token.is_punct == False) and (token.is_stop == False)]
  tokens = [''.join(x.split()) for x in tokens if x] #remove multiple random number leading spaces from each token in a doc
  tokens = [token for token in tokens if token != ''] #remove empty string from leading edges
  return tokens

# %%
from datetime import datetime, date, time, timedelta
import datetime

def wrangle(X):

  ''' wrangle function sort values by api call time and index 
  formats the api call time in usuable features
  filtering data from 28th of MAY when youtube data was ingested cleanly
  keeping 2 months of data for study
  creates tokenised version of username
  creates tokenis version of titles'''

  X = X.sort_values(['api_call_time', 'Unnamed: 0'])
  X['date_api_call_time'] = pd.to_datetime(X['api_call_time']).dt.date
  X['hour_api_call_time']  = pd.to_datetime(X['api_call_time']).dt.hour
  X = X[X['date_api_call_time'] >= datetime.date(2021, 5, 28)]
  X = X[X['date_api_call_time'] <= datetime.date(2021, 7, 28)]
  X.rename(columns={'Unnamed: 0': 'reference_index'}, inplace=True)
  X = X.reset_index(drop=True)
  X['tokenised_title'] = X[X.columns[X.columns.to_series().str.contains('title')]].iloc[:, 0].apply(lambda x : token_text(str(x)))

  #### add in date filter from when data is clean enough

  return X

# %%
def token_text_with_stopwords(doc):


  '''
  tokenising for NLP purposes
  formatting as non html for visualisation
  keep only characters 
  tokenise sentence into words if those words are not punctuation, pronouns or stop words 
  remove potential leading spaces
  '''

  doc = html.parser.unescape(doc) #remove html
  doc = re.sub(r'[^a-zA-Z ^0-9]', '', doc) #keep alphanumerical characters
  doc = re.sub('[0-9]+', '', doc) #remove numerical characters
  doc = doc.lower() #convert all strings to lowercase
  tokens = [token.text for token in tokenizer(doc)  if (token.is_punct == False) ]
  tokens = [''.join(x.split()) for x in tokens if x] #remove multiple random number leading spaces from each token in a doc
  tokens = [token for token in tokens if token != ''] #remove empty string from leading edges
  
  return tokens

# %%
twitch_data = wrangle(twitch_files)
youtube_data = wrangle(youtube_files)

# %%
#tokenising titles and keeping stopwords
twitch_data['tokenised_titles_with_stopwords'] = twitch_data['title'].apply(lambda x: token_text_with_stopwords(str(x)))
youtube_data['tokenised_titles_with_stopwords'] = youtube_data['video_title'].apply(lambda x : token_text_with_stopwords(str(x)))

# %%
print(twitch_data.shape)
print(youtube_data.shape)
# Out:
# (139500, 11)
# (11783, 13)

# %% [markdown]
# ## Adding Twitch Data Genres

# %%
vgsales = pd.read_csv('https://raw.githubusercontent.com/JefNtungila/Sentiment-Analysis-of-Usernames-and-Titles-on-YouTube-and-Twitch/main/data/vgsales.csv')

# %%
#manual labelling of missing top 30 games, often published after 2018
#complementart to classification by VGS which labelled more than 30K titles

game_genre = pd.DataFrame({'game_name': ['Call of Duty: Warzone', 'VALORANT',
       'Hearthstone', 'Genshin Impact', 'FIFA 21', 'Escape from Tarkov',
       'Teamfight Tactics', "Tom Clancy's Rainbow Six Siege", 'SMITE',
       'Resident Evil Village'],
       'game_genre': ['Shooter','Shooter','Misc','Misc','Sports','Shooter','Strategy', 'Shooter', 'Misc', 'Misc']})

# %%
#merging with vgsales
twitch_data = twitch_data.merge(vgsales[['Name', 'Genre']].drop_duplicates(subset= ['Name']), how = 'left', left_on='game_name', right_on='Name')
#merging with modern games dataframe (game_genre)
twitch_data = twitch_data.merge(game_genre, how = 'left', left_on = ['game_name'], right_on = ['game_name'])
twitch_data['Genre'] = twitch_data['Genre'].fillna(twitch_data['game_genre'])
twitch_data['Genre'] = twitch_data['Genre'].fillna('Other')
twitch_data = twitch_data.rename(columns = {'Genre': 'genre'})
twitch_data = twitch_data.drop(columns = ['game_genre', 'Name'])

# %%
twitch_data.columns.values
# Out:
# array(['reference_index', 'user_name', 'game_name', 'title',
#        'viewer_count', 'started_at', 'api_call_time',
#        'date_api_call_time', 'hour_api_call_time', 'tokenised_title',
#        'tokenised_titles_with_stopwords', 'genre'], dtype=object)

# %%
#producing summary statistics for twitch data
#viewer count feature is right skewed min/ max? boxplot???
#bob ross is most occuring title

twitch_data[['reference_index', 'user_name', 'game_name', 'title',
       'viewer_count', 'started_at', 'api_call_time',
       'date_api_call_time', 'hour_api_call_time',  'genre']].describe(include = 'all').T
# Out:
#                      count unique  ...    75%     max
# reference_index     139500    NaN  ...  74.25      99
# user_name           139500   4062  ...    NaN     NaN
# game_name           138386   1378  ...    NaN     NaN
# title               139043  43567  ...    NaN     NaN
# viewer_count        139500    NaN  ...   6788  400648
# started_at          139500  34500  ...    NaN     NaN
# api_call_time       139500   1395  ...    NaN     NaN
# date_api_call_time  139500     62  ...    NaN     NaN
# hour_api_call_time  139500    NaN  ...     18      23
# genre               139500     18  ...    NaN     NaN
#
# [10 rows x 11 columns]

# %% [markdown]
# ## Adding YouTube Genres

# %%
vid_genre = pd.read_csv('https://raw.githubusercontent.com/JefNtungila/Sentiment-Analysis-of-Usernames-and-Titles-on-YouTube-and-Twitch/main/data/Trending_CrowdSourced_Classification.csv', 
                        encoding = 'latin1')
#replacing conventionally viral youtubers with the general youtuber
vid_genre['classification'] = vid_genre['classification'].replace({'CV':'YT'})

#renaming columns to actual words from accronym
vid_genre['classification'] = vid_genre['classification'].replace({'YT': 'Youtuber',
                                                                    'CO': 'Commercial',
                                                                    'TR':'Trailer',
                                                                    'MU': 'Music',
                                                                    'TM': 'Traditional Media'})
vid_genre = vid_genre[vid_genre['classification'].notna()]
vid_genre = vid_genre.rename(columns={'classification':'genre'})

# %%
#merging with the crowdsourced video genre
youtube_data = youtube_data.merge(vid_genre[['channel', 'genre']], how = 'left', left_on='username', right_on='channel')
youtube_data = youtube_data.drop(columns=['channel'])

# %%
from sklearn.feature_extraction.text import CountVectorizer


#creating word scarse count vectorised matric from youtube titles
countvec = CountVectorizer()
df_one_hot_encoded = pd.DataFrame(countvec.fit_transform(youtube_data['video_title']).toarray(), 
                                  index=youtube_data['video_title'], columns=countvec.get_feature_names())

# %%
#adding the target column to the countvectorised matrix

df_processed = pd.concat([df_one_hot_encoded.reset_index(drop=True),  
                          youtube_data['genre'].reset_index(drop = True)], axis = 1)

# %%
import numpy as np
from sklearn.model_selection import train_test_split

#selecting labelled data for training and testing

X = df_processed[df_processed['genre'].notna()].drop(columns= ['genre'])
y = df_processed[df_processed['genre'].notna()]['genre']

#splitting in 80, 20
X_train, X_val, y_train, y_val = train_test_split( X, y, train_size = 0.8, stratify=y, random_state=42)

print(X_train.shape, y_train.shape, X_val.shape, y_val.shape)
# Out:
# (2391, 4757) (2391,) (598, 4757) (598,)

# %% [markdown]
# Reference :
#
# Chen, T. and Guestrin, C., 2016, August. Xgboost: A scalable tree boosting system. In Proceedings of the 22nd acm sigkdd international conference on knowledge discovery and data mining (pp. 785-794).

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.7/dist-packages (0.90)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.4.1)

# %%
from xgboost import XGBClassifier
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score
from sklearn.impute import SimpleImputer



eval_set = [(X_train, y_train), (X_val, y_val)]


# Fit on train, score on val, predict on test, 100 trees, stop after no improvemnt for 30 epochs
model = XGBClassifier(n_estimators = 100, n_jobs = -1)
model.fit(X_train, y_train, eval_set = eval_set , early_stopping_rounds = 30)

y_pred = model.predict(X_val) #actually storing the predictions it would have made for X_val
print('Validation Accuracy', model.score(X_val, y_val))
# Out:
# [0]	validation_0-merror:0.212882	validation_1-merror:0.210702
# Multiple eval metrics have been passed: 'validation_1-merror' will be used for early stopping.
#
# Will train until validation_1-merror hasn't improved in 30 rounds.
# [1]	validation_0-merror:0.193643	validation_1-merror:0.185619
# [2]	validation_0-merror:0.212882	validation_1-merror:0.198997
# [3]	validation_0-merror:0.189879	validation_1-merror:0.182274
# [4]	validation_0-merror:0.186533	validation_1-merror:0.182274
# [5]	validation_0-merror:0.181932	validation_1-merror:0.17893
# [6]	validation_0-merror:0.179423	validation_1-merror:0.17893
# [7]	validation_0-merror:0.179423	validation_1-merror:0.17893
# [8]	validation_0-merror:0.179423	validation_1-merror:0.17893
# [9]	validation_0-merror:0.18486	validation_1-merror:0.183946
# [10]	validation_0-merror:0.184023	validation_1-merror:0.182274
# [11]	validation_0-merror:0.178168	validation_1-merror:0.17893
# [12]	validation_0-merror:0.179841	validation_1-merror:0.17893
# [13]	validation_0-merror:0.178168	validation_1-merror:0.17893
# [14]	validation_0-merror:0.176495	validation_1-merror:0.177258
# [15]	validation_0-merror:0.17524	validation_1-merror:0.175585
# [16]	validation_0-merror:0.165203	validation_1-merror:0.16388
# [17]	validation_0-merror:0.165203	validation_1-merror:0.16388
# [18]	validation_0-merror:0.150146	validation_1-merror:0.152174
# [19]	validation_0-merror:0.145964	validation_1-merror:0.145485
# [20]	validation_0-merror:0.134672	validation_1-merror:0.132107
# [21]	validation_0-merror:0.130908	validation_1-merror:0.12709
# [22]	validation_0-merror:0.125052	validation_1-merror:0.123746
# [23]	validation_0-merror:0.122125	validation_1-merror:0.123746
# [24]	validation_0-merror:0.125052	validation_1-merror:0.123746
# [25]	validation_0-merror:0.125052	validation_1-merror:0.128763
# [26]	validation_0-merror:0.120452	validation_1-merror:0.123746
# [27]	validation_0-merror:0.11376	validation_1-merror:0.113712
# [28]	validation_0-merror:0.113342	validation_1-merror:0.115385
# [29]	validation_0-merror:0.113342	validation_1-merror:0.115385
# [30]	validation_0-merror:0.113342	validation_1-merror:0.115385
# [31]	validation_0-merror:0.113342	validation_1-merror:0.115385
# [32]	validation_0-merror:0.113342	validation_1-merror:0.115385
# [33]	validation_0-merror:0.113342	validation_1-merror:0.115385
# [34]	validation_0-merror:0.112087	validation_1-merror:0.115385
# [35]	validation_0-merror:0.113342	validation_1-merror:0.115385
# [36]	validation_0-merror:0.113342	validation_1-merror:0.115385
# [37]	validation_0-merror:0.111669	validation_1-merror:0.113712
# [38]	validation_0-merror:0.107905	validation_1-merror:0.108696
# [39]	validation_0-merror:0.107905	validation_1-merror:0.108696
# [40]	validation_0-merror:0.107905	validation_1-merror:0.108696
# [41]	validation_0-merror:0.107486	validation_1-merror:0.108696
# [42]	validation_0-merror:0.107486	validation_1-merror:0.108696
# [43]	validation_0-merror:0.106232	validation_1-merror:0.107023
# [44]	validation_0-merror:0.106232	validation_1-merror:0.107023
# [45]	validation_0-merror:0.104559	validation_1-merror:0.105351
# [46]	validation_0-merror:0.095358	validation_1-merror:0.098662
# [47]	validation_0-merror:0.092012	validation_1-merror:0.098662
# [48]	validation_0-merror:0.093266	validation_1-merror:0.100334
# [49]	validation_0-merror:0.092012	validation_1-merror:0.098662
# [50]	validation_0-merror:0.089921	validation_1-merror:0.09699
# [51]	validation_0-merror:0.087411	validation_1-merror:0.093645
# [52]	validation_0-merror:0.085738	validation_1-merror:0.093645
# [53]	validation_0-merror:0.080719	validation_1-merror:0.086957
# [54]	validation_0-merror:0.080719	validation_1-merror:0.086957
# [55]	validation_0-merror:0.079465	validation_1-merror:0.086957
# [56]	validation_0-merror:0.073191	validation_1-merror:0.08194
# [57]	validation_0-merror:0.073191	validation_1-merror:0.08194
# [58]	validation_0-merror:0.070263	validation_1-merror:0.083612
# [59]	validation_0-merror:0.06399	validation_1-merror:0.078595
# [60]	validation_0-merror:0.06399	validation_1-merror:0.078595
# [61]	validation_0-merror:0.062735	validation_1-merror:0.078595
# [62]	validation_0-merror:0.062735	validation_1-merror:0.078595
# [63]	validation_0-merror:0.062735	validation_1-merror:0.078595
# [64]	validation_0-merror:0.061899	validation_1-merror:0.078595
# [65]	validation_0-merror:0.061899	validation_1-merror:0.078595
# [66]	validation_0-merror:0.061899	validation_1-merror:0.078595
# [67]	validation_0-merror:0.061481	validation_1-merror:0.078595
# [68]	validation_0-merror:0.061481	validation_1-merror:0.078595
# [69]	validation_0-merror:0.058135	validation_1-merror:0.073579
# [70]	validation_0-merror:0.058135	validation_1-merror:0.073579
# [71]	validation_0-merror:0.05688	validation_1-merror:0.073579
# [72]	validation_0-merror:0.054789	validation_1-merror:0.071906
# [73]	validation_0-merror:0.054789	validation_1-merror:0.071906
# [74]	validation_0-merror:0.054789	validation_1-merror:0.071906
# [75]	validation_0-merror:0.050188	validation_1-merror:0.071906
# [76]	validation_0-merror:0.049352	validation_1-merror:0.058528
# [77]	validation_0-merror:0.053534	validation_1-merror:0.071906
# [78]	validation_0-merror:0.047261	validation_1-merror:0.058528
# [79]	validation_0-merror:0.046006	validation_1-merror:0.058528
# [80]	validation_0-merror:0.046006	validation_1-merror:0.058528
# [81]	validation_0-merror:0.047261	validation_1-merror:0.058528
# [82]	validation_0-merror:0.047261	validation_1-merror:0.058528
# [83]	validation_0-merror:0.047261	validation_1-merror:0.058528
# [84]	validation_0-merror:0.047261	validation_1-merror:0.058528
# [85]	validation_0-merror:0.047261	validation_1-merror:0.058528
# [86]	validation_0-merror:0.045169	validation_1-merror:0.058528
# [87]	validation_0-merror:0.045169	validation_1-merror:0.058528
# [88]	validation_0-merror:0.046424	validation_1-merror:0.058528
# [89]	validation_0-merror:0.047261	validation_1-merror:0.058528
# [90]	validation_0-merror:0.044751	validation_1-merror:0.051839
# [91]	validation_0-merror:0.044751	validation_1-merror:0.051839
# [92]	validation_0-merror:0.044751	validation_1-merror:0.051839
# [93]	validation_0-merror:0.044751	validation_1-merror:0.051839
# [94]	validation_0-merror:0.044751	validation_1-merror:0.051839
# [95]	validation_0-merror:0.044751	validation_1-merror:0.051839
# [96]	validation_0-merror:0.044751	validation_1-merror:0.051839
# [97]	validation_0-merror:0.044751	validation_1-merror:0.051839
# [98]	validation_0-merror:0.043078	validation_1-merror:0.050167
# [99]	validation_0-merror:0.043078	validation_1-merror:0.050167
# Validation Accuracy 0.9498327759197325

# %%
#predicting genres for those that don't have a genre
pred = model.predict(df_processed[df_processed['genre'].isna()].drop(columns= ['genre']))
index_no_genre = youtube_data[youtube_data['genre'].isna()].reset_index()['index'].tolist()

#creating dataframe with the predicted genres and the row indeces on which they should be merged
pred_df = pd.DataFrame({'label': pred,
                        'index': index_no_genre})

pred_df['label'].value_counts()
# Out:
# Youtuber             5499
# Music                1763
# Traditional Media    1310
# Commercial            151
# Trailer                71
# Name: label, dtype: int64

# %%
#merge original dataframe with new labels
youtube_data = pd.merge(youtube_data.reset_index(), pred_df, how = 'left', on='index')
youtube_data['genre'] = youtube_data['genre'].fillna(youtube_data['label'])
#deleting columns that were used as reference for the merge
youtube_data = youtube_data.drop(columns=['index', 'label'])

# %%
youtube_data[['reference_index', 'username', 'video_title', 'publish_time',
       'view_count', 'comment_count', 'like_count', 'dislike count',
       'api_call_time', 'date_api_call_time', 'hour_api_call_time', 'genre']].describe(include = 'all').T
# Out:
#                     count unique  ...          75%          max
# reference_index     11783    NaN  ...           36           49
# username            11783   1303  ...          NaN          NaN
# video_title         11783   1910  ...          NaN          NaN
# publish_time        11783   1878  ...          NaN          NaN
# view_count          11783    NaN  ...  6.96942e+06  1.50066e+08
# comment_count       11783    NaN  ...        16928   1.1064e+06
# like_count          11783    NaN  ...       360195  7.42521e+06
# dislike count       11783    NaN  ...         7422       252543
# api_call_time       11783    245  ...          NaN          NaN
# date_api_call_time  11783     62  ...          NaN          NaN
# hour_api_call_time  11783    NaN  ...           14           20
# genre               11783      5  ...          NaN          NaN
#
# [12 rows x 11 columns]

# %% [markdown]
# ## Username Wrangling

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.2.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from nltk) (1.15.0)

# %%
import nltk
from nltk import corpus

english_words = nltk.download('words')
english_vocab = set(word.lower() for word in nltk.corpus.words.words())
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.

# %%
def word_finder(name):

  
  #not random , emperic testing gives good result 

  name = name.lower()

  #finding intersection with words in the dictionary
  all_possible_words = {name[i:j + i] for j in range(2, len(name)) for i in range(len(name)- j + 1)}
  all_words = english_vocab.intersection(all_possible_words)
  all_words = list(set(list(all_words)))
  if all_words == []:
    all_words = float('NaN')
  else:
    #transforming list of words into string of words
    all_words = ' '.join(word for word in all_words)
    #removing stopwords
    all_words = [token.text for token in tokenizer(all_words)  if (token.is_stop == False)] 

  return all_words

# %%
youtube_data.columns
# Out:
# Index(['reference_index', 'username', 'video_title', 'publish_time',
#        'view_count', 'comment_count', 'like_count', 'dislike count',
#        'api_call_time', 'date_api_call_time', 'hour_api_call_time',
#        'tokenised_title', 'tokenised_titles_with_stopwords', 'genre'],
#       dtype='object')

# %%
twitch_data['words_in_names'] = twitch_data['user_name'].apply(lambda x : word_finder(x))
youtube_data['words_in_names'] = youtube_data['username'].apply(lambda x : word_finder(x))

# %% [markdown]
# ## Pushing data to drive and GitHub

# %%
from  github import Github

twitch_data.to_csv('twitch_data.csv')
# !cp twitch_data.csv 'drive/My Drive/'

youtube_data.to_csv('youtube_data.csv')
# !cp youtube_data.csv 'drive/My Drive/'

g = Github('github_key')
repo = g.get_repo('github_repo)
#parameters are filename, description, content
#cannot update because file is to big so have to delete and update

repo.create_file('twitch_data.csv', 'twitch hourly top 50 streams', str(twitch_data.to_csv()))
repo.create_file('youtube_data.csv', 'youtube top 100 streams worldwide taken every 6 hours', str(youtube_data.to_csv()))
